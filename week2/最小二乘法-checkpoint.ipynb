# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#导入数据集
data = pd.read_csv(r"boston_housing,csv")

# %%
#创建类
class LR :
    #最小二乘法
    def fit(self,X,y) :
        X = np.asmatrix(X.copy())
        y = np.asmatrix(y).reshape(-1,1)
        self.w_ = (X.T * X).I * X.T * y
        
    def predict(self,X) :
        X = np.asmatrix(X.copy())
        result = X * self.w_
        return np.asarray(result).ravel()

# %%
# 不考虑截距的情况
t = data.sample(len(data),random_state=0)

train_X = t.iloc[:400,:-1]
train_y = t.iloc[:400,-1]

test_X = t.iloc[400:,:-1]
test_y = t.iloc[400:,-1]

# %%
lr = LR()
lr.fit(train_X,train_y)
result = lr.predict(test_X)

# %%
print(result)
display(np.mean((result - test_y)**2))
(lr.w_)
# Out:
# [32.42172415 31.8657517   9.52136202 12.48229778 24.0752596  35.61159169
#  21.87963658 21.83586334 16.13822255 28.48423313 41.28647977 26.0070672
#  40.90725627 24.65197618 22.2287279  11.88538102 14.5199733  13.16619548
#  21.0977285   1.63668138 26.26626362 25.86673712 40.16246266 19.1258097
#  24.32830298 35.13353136 32.25968441  8.93124625 25.58561747 43.81949568
#  19.53189418 20.55379055 24.5683383  18.66213437  6.19091265 20.40754604
#  37.07542018 17.15206598 22.57021671 14.31645882 22.99055777 21.07104457
#  20.68038122 21.46684886 33.637416   22.37838619 29.64746524 34.74371484
#  42.05521487 17.38195016 16.53374748 36.47846766 19.90996409 10.58283639
#  16.4811832  23.49337741 21.52104979 19.00410109 26.06647172 11.47742661
#   7.6341651  21.89711762  8.08465405 25.81009681  3.40571466 27.08371318
#  32.58359789 23.38377005 19.39222026 18.11747402 22.50006341 30.2867425
#  26.4365676  21.56876724 18.75306797  8.16360613 23.72965747 23.78731131
#  24.60109392 14.42930437 21.52170235 20.7752007   8.24604815 23.5059796
#  16.79450829 31.07829138 30.69344088 25.96879379 20.95280418 30.60232461
#  22.95467886 25.10397774 24.52893012 31.73071464 23.3648481  34.07017962
#  15.56951583 18.13689308 21.49207402 40.00040401 26.01632124 19.3351639
#  32.14035474 22.27332117 17.85199065 19.69487888]
# 17.011905533634952
# [[-9.32859692e-02]
#  [ 4.39664692e-02]
#  [ 5.72354432e-03]
#  [ 2.41509608e+00]
#  [-3.31988921e+00]
#  [ 5.59119871e+00]
#  [-2.18905524e-03]
#  [-8.57221736e-01]
#  [ 2.28120616e-01]
#  [-1.18896061e-02]
#  [-2.52710238e-01]
#  [ 1.49077626e-02]
#  [-4.56116634e-01]]

# %%
result
# Out:
# array([32.42172415, 31.8657517 ,  9.52136202, 12.48229778, 24.0752596 ,
#        35.61159169, 21.87963658, 21.83586334, 16.13822255, 28.48423313,
#        41.28647977, 26.0070672 , 40.90725627, 24.65197618, 22.2287279 ,
#        11.88538102, 14.5199733 , 13.16619548, 21.0977285 ,  1.63668138,
#        26.26626362, 25.86673712, 40.16246266, 19.1258097 , 24.32830298,
#        35.13353136, 32.25968441,  8.93124625, 25.58561747, 43.81949568,
#        19.53189418, 20.55379055, 24.5683383 , 18.66213437,  6.19091265,
#        20.40754604, 37.07542018, 17.15206598, 22.57021671, 14.31645882,
#        22.99055777, 21.07104457, 20.68038122, 21.46684886, 33.637416  ,
#        22.37838619, 29.64746524, 34.74371484, 42.05521487, 17.38195016,
#        16.53374748, 36.47846766, 19.90996409, 10.58283639, 16.4811832 ,
#        23.49337741, 21.52104979, 19.00410109, 26.06647172, 11.47742661,
#         7.6341651 , 21.89711762,  8.08465405, 25.81009681,  3.40571466,
#        27.08371318, 32.58359789, 23.38377005, 19.39222026, 18.11747402,
#        22.50006341, 30.2867425 , 26.4365676 , 21.56876724, 18.75306797,
#         8.16360613, 23.72965747, 23.78731131, 24.60109392, 14.42930437,
#        21.52170235, 20.7752007 ,  8.24604815, 23.5059796 , 16.79450829,
#        31.07829138, 30.69344088, 25.96879379, 20.95280418, 30.60232461,
#        22.95467886, 25.10397774, 24.52893012, 31.73071464, 23.3648481 ,
#        34.07017962, 15.56951583, 18.13689308, 21.49207402, 40.00040401,
#        26.01632124, 19.3351639 , 32.14035474, 22.27332117, 17.85199065,
#        19.69487888])

# %%
np.mean((result - test_y)**2)
# Out:
# 17.011905533634952

# %%
lr.w_
# Out:
# matrix([[-9.32859692e-02],
#         [ 4.39664692e-02],
#         [ 5.72354432e-03],
#         [ 2.41509608e+00],
#         [-3.31988921e+00],
#         [ 5.59119871e+00],
#         [-2.18905524e-03],
#         [-8.57221736e-01],
#         [ 2.28120616e-01],
#         [-1.18896061e-02],
#         [-2.52710238e-01],
#         [ 1.49077626e-02],
#         [-4.56116634e-01]])

# %%
plt.rcParams["font.family"] = "SimHei"
plt.rcParams["axes.unicode_minus"] = False

# %%
plt.figure(figsize=(10,8))
plt.plot(result,"bo-",label="预测值")
plt.plot(test_y.values,"ro--",label="真实值")
plt.xlabel("样本序号")
plt.ylabel("房价")
plt.title("线性回归预测--最小二乘法")
plt.legend()
plt.show()
